# %%
from selenium.common.exceptions import NoSuchElementException, ElementClickInterceptedException
from selenium import webdriver
import time
import pandas as pd

# %%
def get_jobs(keyword, num_jobs, verbose, path, slp_time):
    
    '''Gathers jobs as a dataframe, scraped from Glassdoor'''
    
    #Initializing the webdriver
    options = webdriver.ChromeOptions()
    
    #Uncomment the line below if you'd like to scrape without a new Chrome window every time.
#     options.add_argument('headless')
    
    #Change the path to where chromedriver is in your home folder.
    driver = webdriver.Chrome(executable_path=path, options=options)
    driver.set_window_size(1120, 1000)
    
    url = "https://www.glassdoor.com/Job/jobs.htm?suggestCount=0&suggestChosen=false&clickSource=searchBtn&typedKeyword="+keyword+"&sc.keyword="+keyword+"&locT=&locId=&jobType="
#     url = "https://www.glassdoor.com/Job/jobs.htm?suggestCount=0&suggestChosen=false&clickSource=searchBtn&typedKeyword="+keyword+"&locT=&locId=&jobType=&context=Jobs&sc.keyword="+keyword+"&dropdown=0"
#     url = 'https://www.glassdoor.com/Job/jobs.htm?sc.keyword="' + keyword + '"&locT=C&locId=1147401&locKeyword=San%20Francisco,%20CA&jobType=all&fromAge=-1&minSalary=0&includeNoSalaryJobs=true&radius=100&cityId=-1&minRating=0.0&industryId=-1&sgocId=-1&seniorityType=all&companyId=-1&employerSizes=0&applicationType=0&remoteWorkType=0'
    driver.get(url)
    jobs = []

    while len(jobs) < num_jobs:  #If true, should be still looking for new jobs.

        #Let the page load. Change this number based on your internet speed.
        #Or, wait until the webpage is loaded, instead of hardcoding it.
        time.sleep(slp_time)

        #Test for the "Sign Up" prompt and get rid of it.
        try:
            driver.find_element_by_class_name('selected').click()
        except ElementClickInterceptedException:
            pass

        time.sleep(.1)

        try:
            driver.find_element_by_css_selector('[alt="Close"]').click()  #clicking to the X.
        except NoSuchElementException:
            pass
        

        #Going through each job in this page
        job_buttons = driver.find_elements_by_class_name("jl")  #jl for Job Listing. These are the buttons we're going to click.
        
        for job_button in job_buttons:  

            print("Progress: {}".format("" + str(len(jobs)) + "/" + str(num_jobs)))
            if len(jobs) >= num_jobs:
                break

            driver.execute_script("arguments[0].scrollIntoView();", job_button)
            job_button.click()  #You might 
            time.sleep(0.1)
            
            collected_successfully = False
            
            while not collected_successfully:
                try:
                    company_name = driver.find_element_by_xpath('.//div[@class="css-87uc0g e1tk4kwz1"]').text
                    location = driver.find_element_by_xpath('.//div[@class="css-56kyx5 e1tk4kwz5"]').text
                    job_title = driver.find_element_by_xpath('.//div[contains(@class, "css-1vg6q84 e1tk4kwz4")]').text
                    job_description = driver.find_element_by_xpath('.//div[@class="p-std css-1k5huso e856ufb0"]').text
                    collected_successfully = True
                except:
                    time.sleep(.1)

            try:
                salary_estimate = driver.find_element_by_xpath('.//span[@class="css-56kyx5 css-16kxj2j e1wijj242"]').text
#                 and @data-test="detailSalary"
            except NoSuchElementException:
                salary_estimate = -1 #You need to set a "not found value. It's important."
            
            try:
                rating = driver.find_element_by_xpath('.//span[@class="css-1m5m32b e1tk4kwz2"]').text
#                 @data-test="detailRating" and
            except NoSuchElementException:
                rating = -1 #You need to set a "not found value. It's important."

            #Printing for debugging
            if verbose:
                print("Job Title: {}".format(job_title))
                print("Salary Estimate: {}".format(salary_estimate))
                print("Job Description: {}".format(job_description[:500]))
                print("Rating: {}".format(rating))
                print("Company Name: {}".format(company_name))
                print("Location: {}".format(location))

            #Going to the Company tab...
            #clicking on this:
            #<div class="tab" data-tab-type="overview"><span>Company</span></div>
            try:
#                 driver.find_element_by_css_selector('Company').click()
                button = driver.find_element_by_xpath('.//div[@class="tab" and @data-tab-type="overview"]') #.click()
                driver.execute_script("arguments[0].click();", button)
#                 driver.find_element_by_xpath('.//div[@class="tab active" data-test="tab" data-tab-type="overview" data-brandviews=""]').click()
#               <div class="tab active" data-test="tab" data-tab-type="overview" data-brandviews=""><span>Company</span></div>

                try:
                    #<div class="infoEntity">
                    #    <label>Headquarters</label>
                    #    <span class="value">San Francisco, CA</span>
                    #</div>
                    headquarters = driver.find_element_by_xpath('.//div[@class="infoEntity"]//label[text()="Headquarters"]//following-sibling::*').text
                except NoSuchElementException:
                    headquarters = -1

                try:
                    size = driver.find_element_by_xpath('.//div[@class="infoEntity"]//label[text()="Size"]//following-sibling::*').text
                except NoSuchElementException:
                    size = -1

                try:
                    founded = driver.find_element_by_xpath('.//div[@class="infoEntity"]//label[text()="Founded"]//following-sibling::*').text
                except NoSuchElementException:
                    founded = -1

                try:
                    type_of_ownership = driver.find_element_by_xpath('.//div[@class="infoEntity"]//label[text()="Type"]//following-sibling::*').text
                except NoSuchElementException:
                    type_of_ownership = -1

                try:
                    industry = driver.find_element_by_xpath('.//div[@class="infoEntity"]//label[text()="Industry"]//following-sibling::*').text
                except NoSuchElementException:
                    industry = -1

                try:
                    sector = driver.find_element_by_xpath('.//div[@class="infoEntity"]//label[text()="Sector"]//following-sibling::*').text
                except NoSuchElementException:
                    sector = -1

                try:
                    revenue = driver.find_element_by_xpath('.//div[@class="infoEntity"]//label[text()="Revenue"]//following-sibling::*').text
                except NoSuchElementException:
                    revenue = -1

                try:
                    competitors = driver.find_element_by_xpath('.//div[@class="infoEntity"]//label[text()="Competitors"]//following-sibling::*').text
                except NoSuchElementException:
                    competitors = -1

            except NoSuchElementException:  #Rarely, some job postings do not have the "Company" tab.
                headquarters = -1
                size = -1
                founded = -1
                type_of_ownership = -1
                industry = -1
                sector = -1
                revenue = -1
                competitors = -1

                
            if verbose:
                print("Headquarters: {}".format(headquarters))
                print("Size: {}".format(size))
                print("Founded: {}".format(founded))
                print("Type of Ownership: {}".format(type_of_ownership))
                print("Industry: {}".format(industry))
                print("Sector: {}".format(sector))
                print("Revenue: {}".format(revenue))
                print("Competitors: {}".format(competitors))
                print("@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@")

            jobs.append({"Job Title" : job_title,
            "Salary Estimate" : salary_estimate,
            "Job Description" : job_description,
            "Rating" : rating,
            "Company Name" : company_name,
            "Location" : location,
            "Headquarters" : headquarters,
            "Size" : size,
            "Founded" : founded,
            "Type of ownership" : type_of_ownership,
            "Industry" : industry,
            "Sector" : sector,
            "Revenue" : revenue,
            "Competitors" : competitors})
            #add job to jobs

        #Clicking on the "next page" button
        try:
            driver.find_element_by_xpath('.//li[@class="next"]//a').click()
        except NoSuchElementException:
            print("Scraping terminated before reaching target number of jobs. Needed {}, got {}.".format(num_jobs, len(jobs)))
            break

    return pd.DataFrame(jobs)  #This line converts the dictionary object into a pandas DataFrame.

# %%
path = "/Users/nicholaskeefer/Downloads/chromedriver 3"

df = get_jobs('data scientist', 2000, False, path, .1)
# Out:
# Progress: 0/2000
# Progress: 1/2000
# Progress: 2/2000
# Progress: 3/2000
# Progress: 4/2000
# Progress: 5/2000
# Progress: 6/2000
# Progress: 7/2000
# Progress: 8/2000
# Progress: 9/2000
# Progress: 10/2000
# Progress: 11/2000
# Progress: 12/2000
# Progress: 13/2000
# Progress: 14/2000
# Progress: 15/2000
# Progress: 16/2000
# Progress: 17/2000
# Progress: 18/2000
# Progress: 19/2000
# Progress: 20/2000
# Progress: 21/2000
# Progress: 22/2000
# Progress: 23/2000
# Progress: 24/2000
# Progress: 25/2000
# Progress: 26/2000
# Progress: 27/2000
# Progress: 28/2000
# Progress: 29/2000
# Progress: 30/2000
# Progress: 31/2000
# Progress: 32/2000
# Progress: 33/2000
# Progress: 34/2000
# Progress: 35/2000
# Progress: 36/2000
# Progress: 37/2000
# Progress: 38/2000
# Progress: 39/2000
# Progress: 40/2000
# Progress: 41/2000
# Progress: 42/2000
# Progress: 43/2000
# Progress: 44/2000
# Progress: 45/2000
# Progress: 46/2000
# Progress: 47/2000
# Progress: 48/2000
# Progress: 49/2000
# Progress: 50/2000
# Progress: 51/2000
# Progress: 52/2000
# Progress: 53/2000
# Progress: 54/2000
# Progress: 55/2000
# Progress: 56/2000
# Progress: 57/2000
# Progress: 58/2000
# Progress: 59/2000
# Progress: 60/2000
# Progress: 61/2000
# Progress: 62/2000
# Progress: 63/2000
# Progress: 64/2000
# Progress: 65/2000
# Progress: 66/2000
# Progress: 67/2000
# Progress: 68/2000
# Progress: 69/2000
# Progress: 70/2000
# Progress: 71/2000
# Progress: 72/2000
# Progress: 73/2000
# Progress: 74/2000
# Progress: 75/2000
# Progress: 76/2000
# Progress: 77/2000
# Progress: 78/2000
# Progress: 79/2000
# Progress: 80/2000
# Progress: 81/2000
# Progress: 82/2000
# Progress: 83/2000
# Progress: 84/2000
# Progress: 85/2000
# Progress: 86/2000
# Progress: 87/2000
# Progress: 88/2000
# Progress: 89/2000
# Progress: 90/2000
# Progress: 91/2000
# Progress: 92/2000
# Progress: 93/2000
# Progress: 94/2000
# Progress: 95/2000
# Progress: 96/2000
# Progress: 97/2000
# Progress: 98/2000
# Progress: 99/2000
# Progress: 100/2000
# Progress: 101/2000
# Progress: 102/2000
# Progress: 103/2000
# Progress: 104/2000
# Progress: 105/2000
# Progress: 106/2000
# Progress: 107/2000
# Progress: 108/2000
# Progress: 109/2000
# Progress: 110/2000
# Progress: 111/2000
# Progress: 112/2000
# Progress: 113/2000
# Progress: 114/2000
# Progress: 115/2000
# Progress: 116/2000
# Progress: 117/2000
# Progress: 118/2000
# Progress: 119/2000
# Progress: 120/2000
# Progress: 121/2000
# Progress: 122/2000
# Progress: 123/2000
# Progress: 124/2000
# Progress: 125/2000
# Progress: 126/2000
# Progress: 127/2000
# Progress: 128/2000
# Progress: 129/2000
# Progress: 130/2000
# Progress: 131/2000
# Progress: 132/2000
# Progress: 133/2000
# Progress: 134/2000
# Progress: 135/2000
# Progress: 136/2000
# Progress: 137/2000
# Progress: 138/2000
# Progress: 139/2000
# Progress: 140/2000
# Progress: 141/2000
# Progress: 142/2000
# Progress: 143/2000
# Progress: 144/2000
# Progress: 145/2000
# Progress: 146/2000
# Progress: 147/2000
# Progress: 148/2000
# Progress: 149/2000
# Progress: 150/2000
# Progress: 151/2000
# Progress: 152/2000
# Progress: 153/2000
# Progress: 154/2000
# Progress: 155/2000
# Progress: 156/2000
# Progress: 157/2000
# Progress: 158/2000
# Progress: 159/2000
# Progress: 160/2000
# Progress: 161/2000
# Progress: 162/2000
# Progress: 163/2000
# Progress: 164/2000
# Progress: 165/2000
# Progress: 166/2000
# Progress: 167/2000
# Progress: 168/2000
# Progress: 169/2000
# Progress: 170/2000
# Progress: 171/2000
# Progress: 172/2000
# Progress: 173/2000
# Progress: 174/2000
# Progress: 175/2000
# Progress: 176/2000
# Progress: 177/2000
# Progress: 178/2000
# Progress: 179/2000
# Progress: 180/2000
# Progress: 181/2000
# Progress: 182/2000
# Progress: 183/2000
# Progress: 184/2000
# Progress: 185/2000
# Progress: 186/2000
# Progress: 187/2000
# Progress: 188/2000
# Progress: 189/2000
# Progress: 190/2000
# Progress: 191/2000
# Progress: 192/2000
# Progress: 193/2000
# Progress: 194/2000
# Progress: 195/2000
# Progress: 196/2000
# Progress: 197/2000
# Progress: 198/2000
# Progress: 199/2000
# Progress: 200/2000
# Progress: 201/2000
# Progress: 202/2000
# Progress: 203/2000
# Progress: 204/2000
# Progress: 205/2000
# Progress: 206/2000
# Progress: 207/2000
# Progress: 208/2000
# Progress: 209/2000
# Progress: 210/2000
# Progress: 211/2000
# Progress: 212/2000
# Progress: 213/2000
# Progress: 214/2000
# Progress: 215/2000
# Progress: 216/2000
# Progress: 217/2000
# Progress: 218/2000
# Progress: 219/2000
# Progress: 220/2000
# Progress: 221/2000
# Progress: 222/2000
# ---------------------------------------------------------------------------
# StaleElementReferenceException            Traceback (most recent call last)
# <ipython-input-44-226d0f0e7dc2> in <module>
#       1 path = "/Users/nicholaskeefer/Downloads/chromedriver 3"
#       2
# ----> 3 df = get_jobs('data scientist', 2000, False, path, .1)
#
# <ipython-input-43-85ffe0f716b5> in get_jobs(keyword, num_jobs, verbose, path, slp_time)
#      49
#      50             driver.execute_script("arguments[0].scrollIntoView();", job_button)
# ---> 51             job_button.click()  #You might
#      52             time.sleep(0.1)
#      53
#
# ~/anaconda3/lib/python3.6/site-packages/selenium/webdriver/remote/webelement.py in click(self)
#      78     def click(self):
#      79         """Clicks the element."""
# ---> 80         self._execute(Command.CLICK_ELEMENT)
#      81
#      82     def submit(self):
#
# ~/anaconda3/lib/python3.6/site-packages/selenium/webdriver/remote/webelement.py in _execute(self, command, params)
#     631             params = {}
#     632         params['id'] = self._id
# --> 633         return self._parent.execute(command, params)
#     634
#     635     def find_element(self, by=By.ID, value=None):
#
# ~/anaconda3/lib/python3.6/site-packages/selenium/webdriver/remote/webdriver.py in execute(self, driver_command, params)
#     319         response = self.command_executor.execute(driver_command, params)
#     320         if response:
# --> 321             self.error_handler.check_response(response)
#     322             response['value'] = self._unwrap_value(
#     323                 response.get('value', None))
#
# ~/anaconda3/lib/python3.6/site-packages/selenium/webdriver/remote/errorhandler.py in check_response(self, response)
#     240                 alert_text = value['alert'].get('text')
#     241             raise exception_class(message, screen, stacktrace, alert_text)
# --> 242         raise exception_class(message, screen, stacktrace)
#     243
#     244     def _value_or_default(self, obj, key, default):
#
# StaleElementReferenceException: Message: stale element reference: element is not attached to the page document
#   (Session info: chrome=87.0.4280.141)

# %%
df.shape
# Out:
# (500, 14)

# %%
df_safe = df.copy()

# %%
df_safe.to_csv('glassdoor_safe.csv')

# %%
df_min.shape
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-27-037d1b929d75> in <module>
#       1
# ----> 2 df_min.shape
#
# NameError: name 'df_min' is not defined

# %%
df
# Out:
#                                           Company Name  Competitors Founded  \
# 0    Johns Hopkins Applied Physics Laboratory (APL)...           -1    1942
# 1              U.S. Customs and Border Protection\n3.7           -1    1927
# 2                                      Austal USA\n3.1           -1    1988
# 3                             United Therapeutics\n3.5           -1    1996
# 4                                     LGC Limited\n5.0           -1      -1
# 5                                    Metron, Inc.\n3.0           -1      -1
# 6                                          Leidos\n3.8           -1    1969
# 7                                    Plante Moran\n4.0           -1    1924
# 8                        Barnes & Noble Education\n3.5           -1    1965
# 9                                           Uline\n3.7           -1    1980
# 10                 Palo Verde Cancer Specialists - TBO           -1      -1
# 11                                        MDx Partners           -1      -1
# 12                       Cane Bay Partners VI, LLP/CBP           -1      -1
# 13   Johns Hopkins Applied Physics Laboratory (APL)...           -1    1942
# 14                                  Dynatek Labs, Inc.           -1      -1
# 15                                          APMEX\n3.6           -1    2000
# 16                                   Silicon Labs\n4.5           -1    1996
# 17                   Berkeley Research Group, LLC\n3.1           -1    2010
# 18                                          Uline\n3.7           -1    1980
# 19                     America First Credit Union\n3.8           -1    1939
# 20                                          GEICO\n3.5           -1    1936
# 21                                           PS&S\n2.9           -1    1962
# 22                  Mission Rock Residential, LLC\n4.2           -1    2012
# 23                         Amneal Pharmaceuticals\n3.4           -1    2002
# 24                                  Bell Partners\n3.6           -1    1976
# 25                                        Emerson\n3.7           -1    1890
# 26                                       BombBomb\n4.1           -1    2006
# 27                                     SSM Health\n3.6           -1    1874
# 28                                                MBDC           -1      -1
# 29                               AutomationDirect\n4.2           -1    1994
# ..                                                 ...          ...     ...
# 470                                      Facebook\n4.5           -1    2004
# 471                                    MightyHive\n4.2           -1    2012
# 472                                    MightyHive\n4.2           -1      -1
# 473               Global Atlantic Financial Group\n4.5           -1    2004
# 474                                    Triplebyte\n3.1           -1    2015
# 475                                        Kharon\n5.0           -1    2017
# 476              Hyundai America Technical Center\n2.9           -1    1986
# 477                                 Rhombus Power\n4.7           -1      -1
# 478                                 LPL Financial\n3.6           -1    1968
# 479                                        Roblox\n4.5           -1    2006
# 480                                       Walmart\n3.3           -1    1962
# 481                         Qualcomm Incorporated\n4.1           -1    1985
# 482                                 Joby Aviation\n4.1           -1      -1
# 483                                        Natera\n4.0           -1    2004
# 484                                   Gradient AI\n4.8           -1    2018
# 485                                    Pixability\n4.1           -1    2008
# 486                              Red Hat Software\n4.2           -1    1993
# 487                                     EnergyHub\n4.5           -1    2007
# 488                                  Stride, Inc.\n3.3           -1    1999
# 489                  Southwest Research Institute\n4.0           -1    1947
# 490                                TraceLink,Inc.\n3.8           -1    2009
# 491                               Havas Worldwide\n3.4           -1    1999
# 492                             Abnormal Security\n4.1           -1    2018
# 493                                      Unilever\n4.1           -1    1872
# 494                                          CCRi\n4.5           -1    1989
# 495                     LexisNexis Risk Solutions\n3.7           -1    2000
# 496                               Havas Worldwide\n3.4           -1    1999
# 497                                      Unilever\n4.1           -1    1872
# 498                             Abnormal Security\n4.1           -1    2018
# 499                                          CCRi\n4.5           -1    1989
#
#      Headquarters                                 Industry  \
# 0              -1                      Aerospace & Defense
# 1              -1                         Federal Agencies
# 2              -1                 Industrial Manufacturing
# 3              -1                Biotech & Pharmaceuticals
# 4              -1                                       -1
# 5              -1    Electrical & Electronic Manufacturing
# 6              -1                      Aerospace & Defense
# 7              -1                               Accounting
# 8              -1      Media & Entertainment Retail Stores
# 9              -1                                Wholesale
# 10             -1                                       -1
# 11             -1                                       -1
# 12             -1                                       -1
# 13             -1                      Aerospace & Defense
# 14             -1                                       -1
# 15             -1                      Other Retail Stores
# 16             -1    Electrical & Electronic Manufacturing
# 17             -1                               Consulting
# 18             -1                                Wholesale
# 19             -1    Investment Banking & Asset Management
# 20             -1                       Insurance Carriers
# 21             -1     Architectural & Engineering Services
# 22             -1                              Real Estate
# 23             -1                Biotech & Pharmaceuticals
# 24             -1                              Real Estate
# 25             -1    Electrical & Electronic Manufacturing
# 26             -1                                 Internet
# 27             -1         Health Care Services & Hospitals
# 28             -1                                       -1
# 29             -1                      Other Retail Stores
# ..            ...                                      ...
# 470            -1                                 Internet
# 471            -1                  Advertising & Marketing
# 472            -1                                       -1
# 473            -1                       Insurance Carriers
# 474            -1             Computer Hardware & Software
# 475            -1                                       -1
# 476            -1   Transportation Equipment Manufacturing
# 477            -1                                       -1
# 478            -1    Investment Banking & Asset Management
# 479            -1             Computer Hardware & Software
# 480            -1      Department, Clothing, & Shoe Stores
# 481            -1             Computer Hardware & Software
# 482            -1                                       -1
# 483            -1                Biotech & Pharmaceuticals
# 484            -1  Enterprise Software & Network Solutions
# 485            -1                  Advertising & Marketing
# 486            -1             Computer Hardware & Software
# 487            -1             Computer Hardware & Software
# 488            -1                           K-12 Education
# 489            -1                   Research & Development
# 490            -1  Enterprise Software & Network Solutions
# 491            -1                  Advertising & Marketing
# 492            -1  Enterprise Software & Network Solutions
# 493            -1          Consumer Products Manufacturing
# 494            -1                      Aerospace & Defense
# 495            -1                               Consulting
# 496            -1                  Advertising & Marketing
# 497            -1          Consumer Products Manufacturing
# 498            -1  Enterprise Software & Network Solutions
# 499            -1                      Aerospace & Defense
#
#                                        Job Description  \
# 0    Are you passionate about providing real impact...
# 1    Duties\nSummary\nAs our nation navigates the C...
# 2    Any qualified individual with a disability who...
# 3    What we do\nAbout United Therapeutics\nUnited ...
# 4    Position Summary: LGC Biosearch Technologies i...
# 5    Job Description:\nOur Reston office is seeking...
# 6    Description\nJob Description:\nThe Defense Gro...
# 7    Make your mark. With more than $17.2 billion o...
# 8    JOB TITLE: Data Analyst - Product Development ...
# 9    Supply Chain Data Analyst\nCorporate Headquart...
# 10   RESPONSIBILITIES:\nIndependently perform clini...
# 11   Job Summary:\nResponsible for performing techn...
# 12   Key Responsibilities\nDevelop and execute risk...
# 13   Are you passionate about using data visualizat...
# 14   Small high tech company looking for an experie...
# 15   Business Intelligence Analyst\n\nJob Details\n...
# 16   More About Silicon Labs:\n\nWe are Silicon Lab...
# 17   The Berkeley Research Group, LLC (BRG) Healthc...
# 18   Data Analyst\nCorporate Headquarters\n12575 Ul...
# 19   Overview:\nThe Digital Engagement Data Analyst...
# 20   Working out of our Chevy Chase, MD/Washington ...
# 21   Overview:\nPS&S is an award-winning “one-stop ...
# 22   The Data Analyst is responsible for the design...
# 23   The Scientist 3 - QC is responsible to perform...
# 24   This position will be responsible for the deve...
# 25   At Emerson, we are innovators and problem-solv...
# 26   Who we are...\n\nConnecting people in a more m...
# 27   This position will report under the Corporate ...
# 28   MBDC (McDonough Braungart Design Chemistry) is...
# 29   Business Intelligence Analyst\n\nObjective\nTh...
# ..                                                 ...
# 470  We’re looking for Data Scientists to work on o...
# 471  The Opportunity\nMightyHive is the leading dat...
# 472  The Opportunity\nMightyHive is the leading dat...
# 473  **We are still hiring and interviewing for thi...
# 474  Role Description\nAs a data scientist at Tripl...
# 475  Company:\n\nKharon is a leading source for ana...
# 476  Job Description:\n\nHyundai Motor Groupis at t...
# 477  Are you bold, smart, and curious? Are you eage...
# 478  Do you a passion for applying analytics tools ...
# 479  WHY ROBLOX?\n\nRoblox is ushering in the next ...
# 480  Position Summary...\nWhat you'll do...\n\n\nWh...
# 481  Company:\nQualcomm Technologies, Inc.\nJob Are...
# 482  Located in Northern California, the Joby Aviat...
# 483  POSITION SUMMARY\n\nThe Data Scientist partici...
# 484  About Gradient AI:\n\nGradient AI delivers sta...
# 485  Who We Are\n\nPixability is a video technology...
# 486  Job summary:\nThe Red Hat Global Finance team ...
# 487  EnergyHub is seeking a Data Scientist for our ...
# 488  Meet Stride\nSuccess Stories\nResponsibility a...
# 489  Job Summary:\n\n\nJoin our Intelligent Systems...
# 490  The emerging next-generation pharmaceutical su...
# 491  Agency :\n\nHavas Edge San Diego\n\nJob Descri...
# 492  ABNORMAL SECURITY.\n\nAbnormal Security is def...
# 493  Background & Purpose of the Job\n\nUnilever Fo...
# 494  At CCRi, our clients look to us to solve their...
# 495  LexisNexis Risk Solutions\n\nWe develop indust...
# 496  Agency :\n\nHavas Edge San Diego\n\nJob Descri...
# 497  Background & Purpose of the Job\n\nUnilever Fo...
# 498  ABNORMAL SECURITY.\n\nAbnormal Security is def...
# 499  At CCRi, our clients look to us to solve their...
#
#                                              Job Title  \
# 0                                       Data Scientist
# 1           HR Specialist (Data Scientist) - 1.15.2021
# 2                                     HCM Data Analyst
# 3                        Product Development Scientist
# 4                                Senior Scientist, R&D
# 5                                   Research Scientist
# 6                                       Data Scientist
# 7                              Operations Data Analyst
# 8       Data Analyst - Product Development (eCommerce)
# 9       Supply Chain Data Analyst (South of Milwaukee)
# 10   Flow Cytometry Clinical Laboratory Scientist -...
# 11   Next Generation Sequencing Clinical Lab Scient...
# 12                              Risk Analytics Manager
# 13                        Data Visualization Scientist
# 14                                       Lab Scientist
# 15                       Business Intelligence Analyst
# 16                               Data Scientist Intern
# 17                     Healthcare Analytics Consultant
# 18                                        Data Analyst
# 19               Digital Engagement Data Analyst/Admin
# 20                            Principal Data Scientist
# 21                       Permitting/ Wetland Scientist
# 22                              Data Analyst (Finance)
# 23                      Scientist III, Quality Control
# 24                                        Data Analyst
# 25                                        Data Analyst
# 26                                Junior Data Engineer
# 27                               Data Scientist Senior
# 28                      Senior Environmental Scientist
# 29                       Business Intelligence Analyst
# ..                                                 ...
# 470                  Data Scientist, Product Analytics
# 471                                     Data Scientist
# 472                                     Data Scientist
# 473  AVP, Data Scientist (Virtual / Remote - Greate...
# 474                                     Data Scientist
# 475                                     Data Scientist
# 476                                     Data Scientist
# 477                                     Data Scientist
# 478                                     Data Scientist
# 479                         Data Scientist - Discovery
# 480                                     Data Scientist
# 481  XR Research Computer Vision and Machine Learni...
# 482                                     Data Scientist
# 483                                     Data Scientist
# 484                                     Data Scientist
# 485                                     Data Scientist
# 486                                     Data Scientist
# 487                                     Data Scientist
# 488                                     Data Scientist
# 489  COMPUTER SCIENTIST - ENGINEER - RESEARCH ENGIN...
# 490                                     Data Scientist
# 491                                     Data Scientist
# 492                                     Data Scientist
# 493                                     Data Scientist
# 494                                     Data Scientist
# 495                                     Data Scientist
# 496                                     Data Scientist
# 497                                     Data Scientist
# 498                                     Data Scientist
# 499                                     Data Scientist
#
#                        Location Rating                           Revenue  \
# 0                    Laurel, MD    4.7            $1 to $2 billion (USD)
# 1                Washington, DC    3.7        Less than $1 million (USD)
# 2                    Mobile, AL    3.1            $1 to $2 billion (USD)
# 3    Research Triangle Park, NC    3.5            $1 to $2 billion (USD)
# 4                  Petaluma, CA    5.0        Less than $1 million (USD)
# 5                    Reston, VA    3.0          $25 to $50 million (USD)
# 6                Fort Meade, MD    3.8                $10+ billion (USD)
# 7                 Kalamazoo, MI    4.0  $500 million to $1 billion (USD)
# 8                    Boston, MA    3.5            $1 to $2 billion (USD)
# 9                 Milwaukee, WI    3.7          Unknown / Non-Applicable
# 10                 Glendale, AZ     -1                                -1
# 11         Saint Petersburg, FL     -1                                -1
# 12            Christiansted, VI     -1                                -1
# 13                   Laurel, MD    4.7            $1 to $2 billion (USD)
# 14                   Galena, MO     -1                                -1
# 15            Oklahoma City, OK    3.6            $1 to $2 billion (USD)
# 16                   Austin, TX    4.5  $500 million to $1 billion (USD)
# 17                    Tampa, FL    3.1          Unknown / Non-Applicable
# 18         Pleasant Prairie, WI    3.7          Unknown / Non-Applicable
# 19                    Ogden, UT    3.8        $100 to $500 million (USD)
# 20              Chevy Chase, MD    3.5                $10+ billion (USD)
# 21            Wall Township, NJ    2.9         $50 to $100 million (USD)
# 22                   Denver, CO    4.2          Unknown / Non-Applicable
# 23               Brookhaven, NY    3.4            $1 to $2 billion (USD)
# 24                  Raleigh, NC    3.6         $50 to $100 million (USD)
# 25                   Dayton, OH    3.7                $10+ billion (USD)
# 26                     Colorado    4.1          Unknown / Non-Applicable
# 27              Saint Louis, MO    3.6            $2 to $5 billion (USD)
# 28          Charlottesville, VA     -1                                -1
# 29                  Cumming, GA    4.2          Unknown / Non-Applicable
# ..                          ...    ...                               ...
# 470              Menlo Park, CA    4.5           $5 to $10 billion (USD)
# 471           San Francisco, CA    4.2          Unknown / Non-Applicable
# 472           San Francisco, CA    4.2                                -1
# 473               Massachusetts    4.5          Unknown / Non-Applicable
# 474           San Francisco, CA    3.1          Unknown / Non-Applicable
# 475             Los Angeles, CA    5.0           $5 to $10 million (USD)
# 476           Mountain View, CA    2.9         $50 to $100 million (USD)
# 477           Mountain View, CA    4.7        Less than $1 million (USD)
# 478               San Diego, CA    3.6            $2 to $5 billion (USD)
# 479               San Mateo, CA    4.5          Unknown / Non-Applicable
# 480               Sunnyvale, CA    3.3                $10+ billion (USD)
# 481               San Diego, CA    4.1                $10+ billion (USD)
# 482              San Carlos, CA    4.1        Less than $1 million (USD)
# 483              San Carlos, CA    4.0        $100 to $500 million (USD)
# 484                  Boston, MA    4.8          Unknown / Non-Applicable
# 485                New York, NY    4.1          $25 to $50 million (USD)
# 486                 Raleigh, NC    4.2            $2 to $5 billion (USD)
# 487                New York, NY    4.5          $10 to $25 million (USD)
# 488                 Herndon, VA    3.3  $500 million to $1 billion (USD)
# 489             San Antonio, TX    4.0  $500 million to $1 billion (USD)
# 490           North Reading, MA    3.8          Unknown / Non-Applicable
# 491                  Dallas, TX    3.4          Unknown / Non-Applicable
# 492                New York, NY    4.1          Unknown / Non-Applicable
# 493               United States    4.1                $10+ billion (USD)
# 494         Charlottesville, VA    4.5          $10 to $25 million (USD)
# 495                Woodbury, MN    3.7            $2 to $5 billion (USD)
# 496                  Dallas, TX    3.4          Unknown / Non-Applicable
# 497               United States    4.1                $10+ billion (USD)
# 498                New York, NY    4.1          Unknown / Non-Applicable
# 499         Charlottesville, VA    4.5          $10 to $25 million (USD)
#
#                     Salary Estimate                     Sector  \
# 0    $100K - $160K (Glassdoor est.)        Aerospace & Defense
# 1     $62K - $137K (Glassdoor est.)                 Government
# 2      $55K - $94K (Glassdoor est.)              Manufacturing
# 3      $11K - $96K (Glassdoor est.)  Biotech & Pharmaceuticals
# 4                                -1                         -1
# 5                                -1              Manufacturing
# 6     $82K - $135K (Glassdoor est.)        Aerospace & Defense
# 7      $36K - $62K (Glassdoor est.)         Accounting & Legal
# 8      $37K - $66K (Glassdoor est.)                     Retail
# 9       $65K - $79K (Employer est.)          Business Services
# 10                               -1                         -1
# 11                               -1                         -1
# 12                               -1                         -1
# 13    $79K - $136K (Glassdoor est.)        Aerospace & Defense
# 14                               -1                         -1
# 15     $43K - $87K (Glassdoor est.)                     Retail
# 16                               -1              Manufacturing
# 17     $48K - $74K (Glassdoor est.)          Business Services
# 18      $65K - $79K (Employer est.)          Business Services
# 19     $34K - $61K (Glassdoor est.)                    Finance
# 20   $104K - $170K (Glassdoor est.)                  Insurance
# 21     $45K - $70K (Glassdoor est.)          Business Services
# 22     $38K - $66K (Glassdoor est.)                Real Estate
# 23     $35K - $64K (Glassdoor est.)  Biotech & Pharmaceuticals
# 24     $40K - $73K (Glassdoor est.)                Real Estate
# 25     $47K - $84K (Glassdoor est.)              Manufacturing
# 26                               -1     Information Technology
# 27    $96K - $153K (Glassdoor est.)                Health Care
# 28                               -1                         -1
# 29                               -1                     Retail
# ..                              ...                        ...
# 470   $89K - $143K (Glassdoor est.)     Information Technology
# 471   $89K - $143K (Glassdoor est.)          Business Services
# 472   $89K - $143K (Glassdoor est.)                         -1
# 473   $89K - $143K (Glassdoor est.)                  Insurance
# 474   $89K - $143K (Glassdoor est.)     Information Technology
# 475   $89K - $143K (Glassdoor est.)                         -1
# 476   $89K - $143K (Glassdoor est.)              Manufacturing
# 477   $89K - $143K (Glassdoor est.)                         -1
# 478   $89K - $143K (Glassdoor est.)                    Finance
# 479   $89K - $143K (Glassdoor est.)     Information Technology
# 480   $89K - $143K (Glassdoor est.)                     Retail
# 481   $89K - $143K (Glassdoor est.)     Information Technology
# 482   $89K - $143K (Glassdoor est.)                         -1
# 483   $89K - $143K (Glassdoor est.)  Biotech & Pharmaceuticals
# 484   $89K - $143K (Glassdoor est.)     Information Technology
# 485   $89K - $143K (Glassdoor est.)          Business Services
# 486   $89K - $143K (Glassdoor est.)     Information Technology
# 487   $89K - $143K (Glassdoor est.)     Information Technology
# 488   $89K - $143K (Glassdoor est.)                  Education
# 489   $89K - $143K (Glassdoor est.)          Business Services
# 490   $89K - $143K (Glassdoor est.)     Information Technology
# 491   $89K - $143K (Glassdoor est.)          Business Services
# 492   $89K - $143K (Glassdoor est.)     Information Technology
# 493   $89K - $143K (Glassdoor est.)              Manufacturing
# 494   $89K - $143K (Glassdoor est.)        Aerospace & Defense
# 495   $89K - $143K (Glassdoor est.)          Business Services
# 496   $67K - $119K (Glassdoor est.)          Business Services
# 497   $67K - $119K (Glassdoor est.)              Manufacturing
# 498   $67K - $119K (Glassdoor est.)     Information Technology
# 499   $67K - $119K (Glassdoor est.)        Aerospace & Defense
#
#                         Size               Type of ownership
# 0    5001 to 10000 Employees          Nonprofit Organization
# 1           10000+ Employees                      Government
# 2     1001 to 5000 Employees                Company - Public
# 3      501 to 1000 Employees                Company - Public
# 4                    Unknown                Company - Public
# 5        51 to 200 Employees               Company - Private
# 6           10000+ Employees                Company - Public
# 7     1001 to 5000 Employees               Company - Private
# 8           10000+ Employees  Subsidiary or Business Segment
# 9    5001 to 10000 Employees               Company - Private
# 10                        -1                              -1
# 11                        -1                              -1
# 12                        -1                              -1
# 13   5001 to 10000 Employees          Nonprofit Organization
# 14                        -1                              -1
# 15      201 to 500 Employees               Company - Private
# 16    1001 to 5000 Employees                Company - Public
# 17    1001 to 5000 Employees               Company - Private
# 18   5001 to 10000 Employees               Company - Private
# 19    1001 to 5000 Employees          Nonprofit Organization
# 20          10000+ Employees  Subsidiary or Business Segment
# 21      201 to 500 Employees               Company - Private
# 22     501 to 1000 Employees               Company - Private
# 23   5001 to 10000 Employees                Company - Public
# 24    1001 to 5000 Employees               Company - Private
# 25          10000+ Employees                Company - Public
# 26       51 to 200 Employees               Company - Private
# 27          10000+ Employees          Nonprofit Organization
# 28                        -1                              -1
# 29      201 to 500 Employees               Company - Private
# ..                       ...                             ...
# 470         10000+ Employees                Company - Public
# 471    501 to 1000 Employees  Subsidiary or Business Segment
# 472                       -1                              -1
# 473   1001 to 5000 Employees               Company - Private
# 474      51 to 200 Employees               Company - Private
# 475      51 to 200 Employees                Company - Public
# 476      51 to 200 Employees  Subsidiary or Business Segment
# 477                  Unknown                Company - Public
# 478   1001 to 5000 Employees                Company - Public
# 479    501 to 1000 Employees               Company - Private
# 480   1001 to 5000 Employees                Company - Public
# 481         10000+ Employees                Company - Public
# 482      51 to 200 Employees               Company - Private
# 483    501 to 1000 Employees                Company - Public
# 484        1 to 50 Employees               Company - Private
# 485      51 to 200 Employees               Company - Private
# 486         10000+ Employees                Company - Public
# 487        1 to 50 Employees  Subsidiary or Business Segment
# 488  5001 to 10000 Employees                Company - Public
# 489   1001 to 5000 Employees          Nonprofit Organization
# 490    501 to 1000 Employees               Company - Private
# 491         10000+ Employees  Subsidiary or Business Segment
# 492      51 to 200 Employees               Company - Private
# 493         10000+ Employees                Company - Public
# 494      51 to 200 Employees               Company - Private
# 495   1001 to 5000 Employees                Company - Public
# 496         10000+ Employees  Subsidiary or Business Segment
# 497         10000+ Employees                Company - Public
# 498      51 to 200 Employees               Company - Private
# 499      51 to 200 Employees               Company - Private
#
# [500 rows x 14 columns]

# %%
df_min
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-28-06fa5cf8b296> in <module>
# ----> 1 df_min
#
# NameError: name 'df_min' is not defined
