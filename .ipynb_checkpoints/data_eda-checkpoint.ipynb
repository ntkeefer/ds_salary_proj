# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('salary_data_cleaned.csv')

# %%
df.head()
# Out:
#                                         Company Name  Founded  \
# 0  Johns Hopkins Applied Physics Laboratory (APL)...     1942
# 1            U.S. Customs and Border Protection\n3.7     1927
# 2                                    Austal USA\n3.1     1988
# 3                           United Therapeutics\n3.5     1996
# 4                                        Leidos\n3.8     1969
#
#                     Industry  \
# 0        Aerospace & Defense
# 1           Federal Agencies
# 2   Industrial Manufacturing
# 3  Biotech & Pharmaceuticals
# 4        Aerospace & Defense
#
#                                      Job Description  \
# 0  Are you passionate about providing real impact...
# 1  Duties\nSummary\nAs our nation navigates the C...
# 2  Any qualified individual with a disability who...
# 3  What we do\nAbout United Therapeutics\nUnited ...
# 4  Description\nJob Description:\nThe Defense Gro...
#
#                                     Job Title                    Location  \
# ...

# %%
df.columns
# Out:
# Index(['Company Name', 'Founded', 'Industry', 'Job Description', 'Job Title',
#        'Location', 'Rating', 'Revenue', 'Salary Estimate', 'Sector', 'Size',
#        'Type of ownership', 'min_salary', 'max_salary', 'avg_salary',
#        'company_txt', 'job_state', 'age', 'python_yn', 'R_yn', 'spark_yn',
#        'aws_yn', 'excel_yn'],
#       dtype='object')

# %%
def title_simplifier(title):
    if 'data scientist' in title.lower():
        return 'data scientist'
    elif 'data engineer' in title.lower():
        return 'data engineer'
    elif 'analyst' in title.lower():
        return 'analyst'
    elif 'machine learning' in title.lower():
        return 'mle'
    elif 'manager' in title.lower():
        return 'manager'
    elif 'director' in title.lower():
        return 'director'
    else:
        return 'na'
    
def seniority(title):
    if 'sr' in title.lower() or 'senior' in title.lower() or 'sr.' in title.lower() or 'lead' in title.lower() or 'principal' in title.lower():
        return 'senior'
    elif 'jr' in title.lower() or 'jr.' in title.lower():
        return 'jr'
    else:
        return 'na'

# %%
df['job_simp'] = df['Job Title'].apply(title_simplifier)

# %%
df['job_simp'].value_counts()
# Out:
# data scientist    246
# na                 93
# analyst            87
# data engineer      34
# mle                15
# manager             8
# director            7
# Name: job_simp, dtype: int64

# %%
df['seniority'] = df['Job Title'].apply(seniority)

# %%
df['seniority'].value_counts()
# Out:
# na        377
# senior    113
# Name: seniority, dtype: int64

# %%
df.job_state.value_counts()
# Out:
#  CA              111
#  VA               44
#  NY               37
#  MA               34
#  MD               25
#  TX               21
#  WI               16
#  PA               15
#  IL               15
#  DC               14
#  WA               13
# Remote            12
#  NJ               11
#  FL               11
# United States     10
#  NC               10
#  MO               10
#  NE                9
#  IN                8
#  GA                7
#  UT                7
#  MI                6
#  OH                6
#  CT                4
#  ME                4
#  TN                4
#  CO                4
#  AL                3
#  MN                3
#  AZ                3
#  OR                2
#  AR                2
# California         1
# Maryland           1
#  RI                1
#  OK                1
#  ID                1
#  KY                1
# Massachusetts      1
#  KS                1
#  DE                1
# Name: job_state, dtype: int64

# %%
df['job_state'] = df.job_state.apply(lambda x: x.strip() if x.strip().lower() != 'California' else 'CA')
df['job_state'] = df.job_state.apply(lambda x: x.strip() if x.strip().lower() != 'Maryland' else 'MD')
df['job_state'] = df.job_state.apply(lambda x: x.strip() if x.strip().lower() != 'Massachusetts' else 'MA')

# %%
df['job_state'].value_counts()
# Out:
# CA               111
# VA                44
# NY                37
# MA                34
# MD                25
# TX                21
# WI                16
# PA                15
# IL                15
# DC                14
# WA                13
# Remote            12
# NJ                11
# FL                11
# MO                10
# United States     10
# NC                10
# NE                 9
# IN                 8
# UT                 7
# GA                 7
# OH                 6
# MI                 6
# CO                 4
# CT                 4
# TN                 4
# ME                 4
# MN                 3
# AL                 3
# AZ                 3
# AR                 2
# OR                 2
# OK                 1
# KY                 1
# DE                 1
# KS                 1
# Maryland           1
# California         1
# ID                 1
# Massachusetts      1
# RI                 1
# Name: job_state, dtype: int64

# %%
df = df[df.job_state != 'Maryland']

# %%
df = df[df.job_state != 'California']

# %%
df = df[df.job_state != 'Massachusetts']

# %%
df['job_state'].value_counts()
# Out:
# CA               111
# VA                44
# NY                37
# MA                34
# MD                25
# TX                21
# WI                16
# PA                15
# IL                15
# DC                14
# WA                13
# Remote            12
# NJ                11
# FL                11
# MO                10
# NC                10
# United States     10
# NE                 9
# IN                 8
# UT                 7
# GA                 7
# MI                 6
# OH                 6
# TN                 4
# CO                 4
# ME                 4
# CT                 4
# AZ                 3
# MN                 3
# AL                 3
# OR                 2
# AR                 2
# OK                 1
# KS                 1
# KY                 1
# DE                 1
# ID                 1
# RI                 1
# Name: job_state, dtype: int64

# %% [markdown]
# ## Job Desc. Length

# %%
df['desc_len'] = df['Job Description'].apply(lambda x: len(x))
df['desc_len']
# Out:
# 0      2923
# 1      2592
# 2      5402
# 3      3733
# 4      4784
# 5      2727
# 6      3527
# 7      2724
# 8      4699
# 9      4261
# 10     5609
# 11     2864
# 12     4782
# 13     5214
# 14     2931
# 15     4179
# 16     5338
# 17     5792
# 18     9277
# 19     3392
# 20     3640
# 21     4907
# 22     5288
# 23     6253
# 24     2198
# 25     5327
# 26     1826
# 27     3495
# 28     3198
# 29     5788
#        ...
# 459    6229
# 460    4310
# 461    3795
# 462    3795
# 464    3451
# 465    3007
# 466    3751
# 467    3046
# 468    6050
# 469    4075
# 470    3470
# 471    4418
# 472    2731
# 473    3745
# 474    2957
# 475    4688
# 476    5110
# 477    4641
# 478    7244
# 479    2537
# 480    2747
# 481    5534
# 482    3134
# 483    7711
# 484    3703
# 485    3980
# 486    5534
# 487    7711
# 488    3134
# 489    3703
# Name: desc_len, Length: 487, dtype: int64

# %%
df.describe()
# Out:
#            Founded      Rating  min_salary  max_salary  avg_salary  \
# count   487.000000  487.000000  487.000000  487.000000  487.000000
# mean   1568.188912    3.245791   81.094456  135.480493  108.287474
# std     809.289198    1.650171   30.433347   44.718727   37.463913
# min      -1.000000   -1.000000   11.000000   61.000000   47.500000
# 25%    1901.500000    3.300000   58.000000  105.000000   81.500000
# 50%    1985.000000    3.700000   87.000000  143.000000  115.500000
# 75%    2006.000000    4.100000  100.000000  162.000000  131.000000
# max    2020.000000    5.000000  146.000000  230.000000  188.000000
#
#               age   python_yn        R_yn    spark_yn      aws_yn    excel_yn  \
# count  487.000000  487.000000  487.000000  487.000000  487.000000  487.000000
# mean    28.312115    0.591376    0.004107    0.160164    0.207392    0.566735
# std     38.352560    0.492085    0.064018    0.367135    0.405856    0.496036
# ...

# %%
df.Rating.hist()

# %%
df.avg_salary.hist()

# %%
df.age.hist()

# %%
df.desc_len.hist()

# %%
df.boxplot(column = ['age', 'avg_salary', 'Rating'])

# %%
df.boxplot(column =  'Rating')

# %%
df[['age', 'avg_salary', 'Rating', 'desc_len']].corr()
# Out:
#                  age  avg_salary    Rating  desc_len
# age         1.000000    0.013577  0.241710  0.186933
# avg_salary  0.013577    1.000000 -0.009561 -0.004592
# Rating      0.241710   -0.009561  1.000000  0.005546
# desc_len    0.186933   -0.004592  0.005546  1.000000

# %%
cmap = sns.diverging_palette(220, 10, as_cmap=True)
sns.heatmap(df[['age', 'avg_salary', 'Rating', 'desc_len']].corr(), vmax=.3, center=0, cmap=cmap, square =True, linewidth=.5, cbar_kws={"shrink": .5})

# %%
df.columns
# Out:
# Index(['Company Name', 'Founded', 'Industry', 'Job Description', 'Job Title',
#        'Location', 'Rating', 'Revenue', 'Salary Estimate', 'Sector', 'Size',
#        'Type of ownership', 'min_salary', 'max_salary', 'avg_salary',
#        'company_txt', 'job_state', 'age', 'python_yn', 'R_yn', 'spark_yn',
#        'aws_yn', 'excel_yn', 'job_simp', 'seniority', 'desc_len'],
#       dtype='object')

# %%
df_cat = df[['Location', 'Size', 'Type of ownership', 'Industry', 'Sector', 'Revenue','company_txt', 'job_state', 'python_yn', 'R_yn', 'spark_yn',
       'aws_yn', 'excel_yn', 'job_simp', 'seniority']]

# %%
for i in df_cat.columns:
    cat_num = df_cat[i].value_counts()
    print("graph for %s: total = %d" % (i, len(cat_num)))
    chart = sns.barplot(x=cat_num.index, y=cat_num)
    chart.set_xticklabels(chart.get_xticklabels(), rotation=90)
    plt.show()
# Out:
# graph for Location: total = 180
# graph for Size: total = 9
# graph for Type of ownership: total = 8
# graph for Industry: total = 56
# graph for Sector: total = 20
# graph for Revenue: total = 14
# graph for company_txt: total = 346
# graph for job_state: total = 38
# graph for python_yn: total = 2
# graph for R_yn: total = 2
# graph for spark_yn: total = 2
# graph for aws_yn: total = 2
# graph for excel_yn: total = 2
# graph for job_simp: total = 7
# graph for seniority: total = 2

# %%
for i in df_cat[['Location', 'company_txt', 'job_state']].columns:
    cat_num = df_cat[i].value_counts()[:20]
    print("graph for %s: total = %d" % (i, len(cat_num)))
    chart = sns.barplot(x=cat_num.index, y=cat_num)
    chart.set_xticklabels(chart.get_xticklabels(), rotation=90)
    plt.show()
# Out:
# graph for Location: total = 20
# graph for company_txt: total = 20
# graph for job_state: total = 20

# %%
df.columns
# Out:
# Index(['Company Name', 'Founded', 'Industry', 'Job Description', 'Job Title',
#        'Location', 'Rating', 'Revenue', 'Salary Estimate', 'Sector', 'Size',
#        'Type of ownership', 'min_salary', 'max_salary', 'avg_salary',
#        'company_txt', 'job_state', 'age', 'python_yn', 'R_yn', 'spark_yn',
#        'aws_yn', 'excel_yn', 'job_simp', 'seniority', 'desc_len'],
#       dtype='object')

# %%
pd.pivot_table(df, index = ['job_simp','seniority'], values = 'avg_salary')
# Out:
#                           avg_salary
# job_simp       seniority
# analyst        na         105.875000
#                senior     108.956522
# data engineer  na         105.950000
#                senior     102.375000
# data scientist na         107.727027
#                senior     111.301724
# director       na          97.625000
#                senior     111.833333
# manager        na         117.166667
#                senior     117.250000
# mle            na          99.363636
#                senior     132.375000
# na             na         108.686667
#                senior     113.527778

# %%
pd.options.display.max_rows
pd.set_option('display.max_rows', None)

# %%
pd.pivot_table(df, index = ['job_state', 'job_simp'], values = 'avg_salary', aggfunc = 'count').sort_values('job_state', ascending = False)
# Out:
#                               avg_salary
# job_state     job_simp
# WI            na                       3
#               mle                      1
#               manager                  1
#               data scientist           1
#               data engineer            2
#               analyst                  8
# WA            na                       5
#               data scientist           1
#               data engineer            1
#               analyst                  6
# VA            data scientist          22
#               data engineer            4
#               analyst                  9
#               mle                      2
#               na                       7
# United States na                       1
#               data scientist           7
#               analyst                  2
# UT            data engineer            2
#               analyst                  3
#               data scientist           2
# ...

# %%
pd.pivot_table(df[df.job_simp == 'data scientist'], index = ['job_state'], values = 'avg_salary').sort_values('avg_salary', ascending = False)
# Out:
#                avg_salary
# job_state
# AZ             188.000000
# WA             188.000000
# OH             137.000000
# NC             134.000000
# MI             129.250000
# WI             127.500000
# PA             127.500000
# Remote         126.277778
# United States  122.357143
# KY             116.500000
# AL             115.500000
# GA             111.500000
# NY             110.879310
# CA             110.676923
# NJ             110.571429
# MD             110.230769
# ME             109.833333
# AR             107.750000
# UT             107.000000
# IL             106.857143
# DC             105.250000
# TN             102.833333
# FL             102.750000
# MA             101.333333
# TX             101.192308
# VA             101.045455
# MN              98.750000
# CO              90.250000
# MO              83.071429
# IN              74.125000
# RI              55.500000

# %%
df.columns
# Out:
# Index(['Company Name', 'Founded', 'Industry', 'Job Description', 'Job Title',
#        'Location', 'Rating', 'Revenue', 'Salary Estimate', 'Sector', 'Size',
#        'Type of ownership', 'min_salary', 'max_salary', 'avg_salary',
#        'company_txt', 'job_state', 'age', 'python_yn', 'R_yn', 'spark_yn',
#        'aws_yn', 'excel_yn', 'job_simp', 'seniority', 'desc_len'],
#       dtype='object')

# %%
#rating, industry, sector, revenue, python, r, spark, aws, excel, desc_len, Type of ownership

# %%
df_pivots = df[['Rating', 'Industry', 'Sector', 'Revenue', 'python_yn', 'R_yn', 'spark_yn', 'aws_yn', 'excel_yn', 'Type of ownership', 'avg_salary']]

# %%
for i in df_pivots.columns:
    print(i)
    print(pd.pivot_table(df_pivots, index = i, values= 'avg_salary').sort_values('avg_salary', ascending=False))
# Out:
# Rating
#         avg_salary
# Rating
#  4.7    128.285714
#  3.8    118.933333
#  3.9    118.892857
#  5.0    116.666667
#  2.1    116.500000
#  4.8    116.000000
# -1.0    111.827586
#  3.3    111.636364
#  3.4    110.166667
#  3.7    110.100000
#  4.0    109.115385
#  3.5    108.157895
#  4.5    108.138889
#  4.6    107.400000
#  4.2    107.222222
#  3.0    104.956522
#  3.6    104.517241
#  4.1    104.222222
#  4.3     99.653846
#  3.2     99.227273
#  1.6     99.000000
#  4.4     98.500000
#  4.9     96.166667
#  3.1     92.333333
#  2.9     90.833333
#  2.8     88.083333
#  2.5     81.500000
#  2.0     74.000000
#  2.7     61.500000
# Industry
#                                           avg_salary
# Industry
# Food & Beverage Stores                    159.500000
# Grantmaking Foundations                   158.500000
# Cable, Internet & Telephone Providers     158.500000
# Insurance Agencies & Brokerages           137.000000
# Health, Beauty, & Fitness                 137.000000
# ...

# %%
pd.pivot_table(df_pivots, index = 'Revenue', columns = 'python_yn', values = 'avg_salary', aggfunc = 'count')
# Out:
# python_yn                          0    1
# Revenue
# $1 to $2 billion (USD)             8   12
# $1 to $5 million (USD)             7    7
# $10 to $25 million (USD)           6   11
# $10+ billion (USD)                15   22
# $100 to $500 million (USD)        18   35
# $2 to $5 billion (USD)            19   11
# $25 to $50 million (USD)          13    8
# $5 to $10 billion (USD)            2   10
# $5 to $10 million (USD)            2    5
# $50 to $100 million (USD)         18   12
# $500 million to $1 billion (USD)   6   17
# -1                                29   25
# Less than $1 million (USD)        13   11
# Unknown / Non-Applicable          43  102

# %%
from wordcloud import WordCloud, ImageColorGenerator, STOPWORDS
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize

# %%
words = " ".join(df['Job Description'])

def punctuation_stop(text):
    """remove puncuation and stop words"""
    filtered = []
    stop_words = set(stopwords.words('english'))
    word_tokens = word_tokenize(text)
    for w in word_tokens:
        if w not in stop_words and w.isalpha():
            filtered.append(w.lower())
    return filtered

words_filtered = punctuation_stop(words)

text = " ".join([ele for ele in words_filtered])

wc = WordCloud(background_color="white", random_state = 1, stopwords = STOPWORDS, max_words = 2000, width = 800, height = 1500)
wc.generate(text)

plt.figure(figsize=[10,10])
plt.imshow(wc,interpolation='bilinear')
plt.axis('off')
plt.show()
